# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
df = pd.read_csv('dt_2001_clean.csv')

# %%
plt.figure(figsize=(8, 5))
plt.plot(df['SPX'][-500:].values,'r')
plt.xlabel('Date')
plt.ylabel('SPY Daily Price')
# Out:
# Text(0, 0.5, 'SPY Daily Price')
